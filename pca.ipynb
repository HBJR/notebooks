# %%
import numpy as np
import pandas as pd
import gensim
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models.phrases import Phrases, Phraser
from gensim import corpora
from pathlib import Path
from sklearn.decomposition import PCA

# %%
data_dir = Path().cwd().parent / "data"

# %%
model0 = Doc2Vec.load("../models/main_model_102_108")

# %%
speaker_tags = model0.dv.index_to_key

embeds = np.array([model0.dv[tag] for tag in speaker_tags])

# %%
pca = PCA(n_components=2)

pca_df = pd.DataFrame(pca.fit_transform(embeds), columns=["pc1", "pc2"])

# %%
pca_df["tag"] = speaker_tags

pca_df[["unique_id","party","congress"]] = pca_df["tag"].str.split('_', n=2, expand=True)
pca_df["speakerid"] = pca_df["congress"] + pca_df["unique_id"] 

def make_id(x): 
    if len(x)==8: 
        x=x+"0"
    if len(x)==7: 
        x=[*x]
        x.insert(2, "1")
        x="".join(x)
    return str(x)

pca_df["speakerid"] = pca_df["speakerid"].map(make_id)

# %%
speakers = pd.read_csv(data_dir / "speakers_all.csv")
speakers["speakerid"] = speakers["speakerid"].map(str)

# %%
pca_df = pca_df.merge(speakers, how="left", on="speakerid")

# %%
pca_df
# Out:
#            pc1        pc2          tag unique_id party congress  speakerid  \
# 0    -5.286919   2.025922  11983_D_102     11983     D      102  102119830
# 1    -6.194284  -2.247623  12090_D_102     12090     D      102  102120900
# 2     5.520672  11.096998  11184_R_102     11184     R      102  102111840
# 3    -2.183232   4.750772  11061_R_102     11061     R      102  102110610
# 4     6.345341   3.366552  11089_D_102     11089     D      102  102110890
# ...        ...        ...          ...       ...   ...      ...        ...
# 3068  0.707791  -1.641502  11673_D_108     11673     D      108  108116730
# 3069  2.407817   0.359756  11550_R_108     11550     R      108  108115500
# 3070 -0.112780  -0.107643  11426_R_108     11426     R      108  108114260
# 3071 -0.673378   0.469160  11636_D_108     11636     D      108  108116360
# 3072  0.109138  -1.616782  11879_D_108     11879     D      108  108118790
#
#          lastname firstname state  district
# 0           HOYER     STENY    MD       5.0
# 1           PRICE     DAVID    NC       4.0
# 2        GINGRICH    NEWTON    GA       6.0
# 3          MICHEL    ROBERT    IL      18.0
# 4         WHITTEN     JAMIE    MS       1.0
# ...           ...       ...   ...       ...
# 3068     CHANDLER       BEN    KY       6.0
# 3069         DEAL    NATHAN    GA      10.0
# 3070      JENKINS   WILLIAM    TN       1.0
# 3071           WU     DAVID    OR       1.0
# 3072  BUTTERFIELD    GEORGE    NC       1.0
#
# [3073 rows x 11 columns]

# %%
pca_df.to_csv(data_dir / "pca_102_108.csv", index=False)

# %%
from sklearn.metrics.pairwise import euclidean_distances, cosine_similarity

# %%
wordlist=[]
for word in model0.wv.key_to_index.keys():
    wordlist.append((word, model0.wv.get_vecattr(word, "count")))
wordlist = sorted(wordlist, key=lambda tup: tup[1], reverse=True)
sorted_vocab = [w for w,c in wordlist if c>100 and c<1000000 and w.count('_')<3]

S = np.zeros((len(sorted_vocab), 2))

for idx, w in enumerate(sorted_vocab):
    S[idx, :] = pca.transform(model0.wv[w].reshape(1,-1))

# %%
pd.DataFrame({'word': sorted_vocab, 'pc1': S.T[0], 'pc2':S.T[1]}).sort_values("pc1").head(20)
# Out:
#                              word       pc1       pc2
# 11242               matters_worse -8.232989 -4.309378
# 9488                    deep_cuts -7.938724 -1.610411
# 9233            civil_rights_laws -7.630497 -1.334454
# 4451                      poorest -7.601690  1.535496
# 7731            domestic_programs -7.536790 -3.108415
# 13320              social_justice -7.511666 -3.326380
# 6814                  child_labor -7.388353 -0.580630
# 17484        legal_representation -7.285821  0.019019
# 2960   congressional_black_caucus -7.191643 -3.361098
# 11327             disenfranchised -7.123498 -0.007255
# 13208                   powerless -7.083407 -0.453246
# 4734       democratic_alternative -6.889727 -1.848428
# 20519          billion_tax_breaks -6.865468 -2.279018
# 12722        minority_communities -6.788864 -3.069140
# 6973                       rushed -6.699677  0.257724
# 6845           denied_opportunity -6.685629 -0.878301
# 11440                people_color -6.684684 -3.184589
# 10163                fair_housing -6.650767 -0.219935
# 13774          progressive_caucus -6.596025 -2.336418
# 14613                   apartheid -6.515376 -0.950366

# %%
pd.DataFrame({'word': sorted_vocab, 'pc1': S.T[0], 'pc2':S.T[1]}).sort_values("pc1").tail(20)
# Out:
#                            word       pc1       pc2
# 3438                  paperwork  5.383968 -0.211211
# 10956       federal_bureaucrats  5.403413 -5.189444
# 6790           parents_teachers  5.405427 -2.828275
# 4327          rules_regulations  5.459419  1.071771
# 4748              border_patrol  5.508176  3.447003
# 4753               south_dakota  5.550333  2.146436
# 9489          dollars_classroom  5.681424 -0.640943
# 2509                bureaucrats  5.694160 -2.181439
# 13038                 overtaxed  5.762327 -1.244048
# 10529               going_broke  5.801149  2.160942
# 5619                lower_taxes  6.154631 -1.490044
# 15180    bureaucracy_washington  6.294699  0.725431
# 8382                    mom_dad  6.440846 -0.284652
# 14824           size_government  6.470026  3.206993
# 6949           government_waste  6.520497 -0.333534
# 6689             tax_limitation  6.570110 -0.692046
# 12076    bureaucrats_washington  6.673588 -2.842252
# 14340                 keep_earn  6.709385 -0.906948
# 8102   national_taxpayers_union  7.176216  0.251321
# 9280         town_hall_meetings  7.749044 -2.973586
